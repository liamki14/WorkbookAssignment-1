# %%
import pandas as pd
Location = (r'C:\Users\liamk\Desktop\USF\BUSINESS INTELLIGENCE\Income.xls')
df
# Out:
#             Areaname  STCOU  PEN010201F  PEN010201D  PEN010201N1  PEN010201N2  \
# 0      UNITED STATES      0           0  8703023000            0            0
# 1            ALABAMA   1000           0   110970011            0            0
# 2        Autauga, AL   1001           0     1095107            0            0
# 3        Baldwin, AL   1003           0     3880963            0            0
# 4        Barbour, AL   1005           0      589412            0            0
# ...              ...    ...         ...         ...          ...          ...
# 3193  Sweetwater, WY  56037           0     1114377            0            0
# 3194       Teton, WY  56039           0     1297806            0            0
# 3195       Uinta, WY  56041           0      519550            0            0
# 3196    Washakie, WY  56043           0      227925            0            0
# 3197      Weston, WY  56045           0      198698            0            0
#
# ...
